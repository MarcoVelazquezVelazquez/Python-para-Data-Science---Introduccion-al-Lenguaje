# %% [markdown]
# #**Python para DS - Introducción al lenguaje**

# %% [markdown]
# Números.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Strings (debe ser en comillas o comillas simples).

# %%
'Marco'
# Out:
# 'Marco'

# %% [markdown]
# Declaración de variable.

# %%
nombre = 'Marco'

# %%
nombre
# Out:
# 'Marco'

# %%
edad = 28

# %%
edad
# Out:
# 28

# %% [markdown]
# #Mi primera función

# %% [markdown]
# Función print.

# %%
print('El nombre es Marco y su edad es 28')
# Out:
# El nombre es Marco y su edad es 28

# %% [markdown]
# Usando variables.

# %%
print(f'El nombre es {nombre} y su edad es {edad}')
# Out:
# El nombre es Marco y su edad es 28

# %% [markdown]
# Crear funciones (def)

# %% [markdown]
# Declarar función.

# %%
def saludar():
  nombre = input('Digite su nombre: ')
  print(f'Hola {nombre}, sea bienvenido/a!!!')

# %% [markdown]
# Invocar función.

# %%
saludar()
# Out:
# Digite su nombre: Marco
# Hola Marco, sea bienvenido/a!!!

# %% [markdown]
# #Función con parámetro.

# %%
nombre = 'Andrea'

# %%
def saludar_con_parametros(nombre):
  print(f'Hola {nombre}, sea bienvenido/a!!!')

# %%
saludar_con_parametros(nombre)
# Out:
# Hola Andrea, sea bienvenido/a!!!

# %% [markdown]
# #Condicionales

# %%
edad = 20

# %%
def verificar_si_puede_conducir(edad):
  if edad >= 18:
    print('Usted tiene edad suficiente para conducir')
  else:
    print('Usted no tiene edad suficiente para conducir')

verificar_si_puede_conducir(edad)
# Out:
# Usted tiene edad suficiente para conducir

# %% [markdown]
# #Condicionales sin parámetro y conversión de tipo de datos.

# %% [markdown]
# input retorna un string.

# %%
def verificar_si_puede_conducir_sin_parametro():
  edad = input('Digite su edad: ')
  edad = int(edad)
  if edad >= 18:
    print('Usted tiene edad suficiente para conducir')
  else:
    print('Usted no tiene edad suficiente para conducir')

verificar_si_puede_conducir_sin_parametro()
# Out:
# Digite su edad: 28
# Usted tiene edad suficiente para conducir

# %% [markdown]
# Creación de listas.

# %%
edad = 28
nombre = 'Marco'

# %%
edades = [18,15,12,45,50]

# %%
edades
# Out:
# [18, 15, 12, 45, 50]

# %% [markdown]
# Función type (permite conocer con qué tipo de datos se está trabajando)

# %%
type(edad)
# Out:
# int

# %%
type(nombre)
# Out:
# str

# %%
type(edades)
# Out:
# list

# %% [markdown]
# Para acceder a los datos de las listas es por medio de índices.

# %%
edades[2]
# Out:
# 12

# %% [markdown]
# Insertar comentarios.

# %%
# [18, 15, 12, 45, 50]
#   0   1   2   3   4
#   0  -4  -3  -2  -1

edades[1]
# Out:
# 15

# %% [markdown]
# Mostrar un rango de valores (el último valor es excluyente).

# %%
edades[0:2]
# Out:
# [18, 15]

# %%
edades[:]
# Out:
# [18, 15, 12, 45, 50]

# %%
edades[1:]
# Out:
# [15, 12, 45, 50]

# %%
edades[-1]
# Out:
# 50

# %%
edades[-3]
# Out:
# 12

# %%
edades[2]
# Out:
# 12

# %% [markdown]
# #Ciclos y Bucles

# %%
#Bucle fuera de la función.
edades = [18,15,12,45,50]

def verificar_si_puede_conducir(edad):

    if edad >= 18:
      print('Usted tiene edad suficiente para conducir')
    else:
      print('Usted no tiene edad suficiente para conducir')

for edad in edades:
  verificar_si_puede_conducir(edad)
# Out:
# Usted tiene edad suficiente para conducir
# Usted no tiene edad suficiente para conducir
# Usted no tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %%
#Bucle dentro de la función.
edades = [18,15,12,45,50]

def verificar_si_puede_conducir_con_bucle(edades):
  for edad in edades:
    if edad >= 18:
      print('Usted tiene edad suficiente para conducir')
    else:
      print('Usted no tiene edad suficiente para conducir')

verificar_si_puede_conducir_con_bucle(edades)
# Out:
# Usted tiene edad suficiente para conducir
# Usted no tiene edad suficiente para conducir
# Usted no tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %% [markdown]
# #Booleano

# %%
edad = 18

# %%
edad >= 18
# Out:
# True

# %%
edad < 18
# Out:
# False

# %%
edad == 18
# Out:
# True

# %% [markdown]
# Agregar valores (booleano) a verificaciones, mediante append.

# %%
verificaciones = []
edades = [13,15,20]
def verificar_si_puede_conducir_bool(verificaciones, edades):
  for edad in edades:
    if edad >= 18:
      verificaciones.append(True)
    else:
      verificaciones.append(False)

  for verificacion in verificaciones:
    if verificacion == True:
      print('Usted tiene edad suficiente para conducir')
    else:
      print('Usted no tiene edad suficiente para conducir')

verificar_si_puede_conducir_bool(verificaciones, edades)
# Out:
# Usted no tiene edad suficiente para conducir
# Usted no tiene edad suficiente para conducir
# Usted tiene edad suficiente para conducir

# %%
verificaciones
# Out:
# [False, False, True]

# %% [markdown]
# #Lista con diferentes tipos de datos.

# %%
persona = ['Mariana', 25, True, 'México']

# %%
persona
# Out:
# ['Mariana', 25, True, 'México']

# %%
for elemento in persona:
  print(f'El elemento {elemento} de la lista es del tipo ', type(elemento))
# Out:
# El elemento Mariana de la lista es del tipo  <class 'str'>
# El elemento 25 de la lista es del tipo  <class 'int'>
# El elemento True de la lista es del tipo  <class 'bool'>
# El elemento México de la lista es del tipo  <class 'str'>

# %% [markdown]
# #Importar bibliotecas/librerías

# %% [markdown]
# Generar número aleatorios.

# %%
from random import randrange, seed

# %%
randrange(0,11)
# Out:
# 5

# %%
notas_matematicas = []

# %%
notas_matematicas.append(randrange(0,11))

# %%
notas_matematicas
# Out:
# [8, 2, 1]

# %% [markdown]
# Loop para imprimir un determinado rango.

# %%
for notas in range(6):
  notas_matematicas.append(randrange(0,11))

# %%
notas_matematicas
# Out:
# [0, 10, 0, 4, 9, 10]

# %% [markdown]
# Función para saber el parámetro de una lista.

# %%
len(notas_matematicas)
# Out:
# 6

# %% [markdown]
# Se utiliza seed para manetener los número aleatorios generados con anterioridad (debe importarse).

# %%
notas_matematicas = []
seed(8)
for notas in range(6):
  notas_matematicas.append(randrange(0,11))

# %%
notas_matematicas
# Out:
# [3, 5, 6, 2, 3, 0]

# %% [markdown]
# #Biblioteca matplotlib para gráficos.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Función list genera una lista.

# %%
list(range(1,7))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = list(range(1,7))
y = notas_matematicas

# %%
plt.plot(x,y, marker = 'o')
plt.title('Gráfico de las notas de matemáticas')
plt.xlabel('Pruebas')
plt.ylabel('Notas')
plt.show()
